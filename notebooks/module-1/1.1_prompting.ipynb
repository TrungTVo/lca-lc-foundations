# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv
from pprint import pprint
from langchain.agents import create_agent
from langchain.messages import HumanMessage

load_dotenv()
# Out:
# True

# %%
agent = create_agent(model="gpt-5-nano")

question: HumanMessage = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    input={"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government, so it has no capital. If you’re thinking of a fictional universe, some books or games do assign capitals to lunar settlements—tell me which one and I can name it.

# %% [markdown]
# ## Create agent with system prompts

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    input={"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# In this sci‑fi setup, the Moon’s capital is Lunaris Prime.
#
# - Location: Nestled on the rim of Shackleton Crater in the Moon’s southern polar region, Lunaris Prime sits beneath a transparent dome that shields a ring of stacked habitats. Subsurface ice and local regolith provide water and shielding from radiation, making it a natural hub for the Moon’s core operations.
#
# - Governance: A Lunar Assembly governs with six seats representing key sectors: Research, Industry, Culture, Security, Ecology, and External Relations. An elected Prime Administrator acts as the executive, coordinating policy with Earthside agencies and orbital allies.
#
# - Cityscape: The city is a vertical-torus of habitats and transit tubes. Basalt towers braided with glass and latticework rise from a central core called the Beacon Spire, which houses communications, climate control, and the main power nexus. Solar fields on the crater rim feed the city, while anti-gravity corridors and magnetized rails weave residents between districts.
#
# - Economy: Heavily powered by solar generation and helium-3 refinement, Lunaris Prime thrives on high-tech manufacturing, biotech hydroponics, cryo-storage services, and orbital logistics. The crater’s perpetually shadowed pockets are mined for volatiles and water ice, then processed in shielded facilities.
#
# - Culture and daily life: Life here blends Earth heritage with frontier pragmatism. Citizens—often nicknamed Luns—move via swift pods and tethered transit lines, spending evenings in domed plazas where Earthrise is visible through透明 skylights. Educational focus leans on planetary protection, lunar geology, and space infrastructure.
#
# - Notable landmarks:
#   - Beacon Spire: The central communications and climate-control hub.
#   - Moon Gate: A ceremonial and practical airlock to Earth’s waystations.
#   - The Echo Chamber: An amphitheater famed for acoustics unique to the Moon’s quiet environment.
#   - Marea Library: A repository of lunar science, converting polar ice data into immersive exhibits.
#
# - Backstory snapshot: Lunaris Prime grew from a phased, cooperative settlement known as the Artemis Accord stations, expanding into a political and economic capital as Earth and lunar colonies interlinked their commerce, defense, and research missions.
#
# If you want a different era, mood, or tone (grim, utopian, militarized, or corporate-dynastic), I can tailor Lunaris Prime accordingly or offer an alternate capital name.

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    input={"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Lunaria

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    input={"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: Selene Prime
# Location: South Pole region, Shackleton Crater vicinity
# Vibe: Futuristic frontier
# Economy: Helium-3 mining, water-ice harvesting, solar-energy production, habitat manufacturing, scientific research and data services

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

scifi_agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = scifi_agent.invoke(
    input={"messages": [question]}
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is the capital of The Moon?', additional_kwargs={}, response_metadata={}, id='51c9aa82-60a7-45a0-8d34-11617dd79199'),
#               AIMessage(content='{\n  "name": "Lunapolis",\n  "location": "Shackleton Crater rim, lunar south pole",\n  "vibe": "Pristine, ceremonial, and highly functional; glass-domed districts glow with solar energy, gravity-tuned transit, and vertical gardens.",\n  "economy": "Helium-3 and water-ice ISRU, lunar logistics and spaceport services, scientific research, data services, and lunar tourism."\n}', additional_kwargs={'parsed': None, 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1963, 'prompt_tokens': 193, 'total_tokens': 2156, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1856, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DS685dp9Yo2sN4oS8RRKic9xGkaCc', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d695b-cb4b-70c3-986f-11ecbb58db24-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 193, 'output_tokens': 1963, 'total_tokens': 2156, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1856}})],
#  'structured_response': CapitalInfo(name='Lunapolis', location='Shackleton Crater rim, lunar south pole', vibe='Pristine, ceremonial, and highly functional; glass-domed districts glow with solar energy, gravity-tuned transit, and vertical gardens.', economy='Helium-3 and water-ice ISRU, lunar logistics and spaceport services, scientific research, data services, and lunar tourism.')}

# %%
response["structured_response"].name
# Out:
# 'Lunapolis'

# %%
capital_info: CapitalInfo = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Lunapolis is a city located at Shackleton Crater rim, lunar south pole
