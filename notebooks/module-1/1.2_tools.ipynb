# %% [markdown]
# ## Tool definition

# %%
from dotenv import load_dotenv
from pprint import pprint
from langchain.tools import tool
from langchain.agents import create_agent
from langchain.messages import HumanMessage

load_dotenv()
# Out:
# True

# %%
@tool
def square_root(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root")
def tool1(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root", description="Calculate the square root of a number")
def tool1(x: float) -> float:
    return x ** 0.5

# %%
tool1.invoke({"x": 467})
# Out:
# 21.61018278497431

# %% [markdown]
# ## Adding to agents

# %%
agent = create_agent(
    model="gpt-5-nano",
    tools=[tool1],
    system_prompt="You are an arithmetic wizard. Use your tools to calculate the square root and square of any number."
)

# %%
question = HumanMessage(content="What is the square root of 467?")

response = agent.invoke(
    input={"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# The square root of 467 is approximately 21.61018278497431 (about 21.6102 when rounded). Would you like me to also compute 467 squared?

# %%
pprint(response['messages'])
# Out:
# [HumanMessage(content='What is the square root of 467?', additional_kwargs={}, response_metadata={}, id='e2f24424-d295-402e-92d2-8ae348f1b51e'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 3992, 'prompt_tokens': 158, 'total_tokens': 4150, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 3968, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DSCbgHl67AsuxeqdbtiqgorAFuaUq', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d6ad7-b83b-71f2-b886-04923e4e5126-0', tool_calls=[{'name': 'square_root', 'args': {'x': 467}, 'id': 'call_nSjfIVuvsMdRanQLvaeoRjX6', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 158, 'output_tokens': 3992, 'total_tokens': 4150, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 3968}}),
#  ToolMessage(content='21.61018278497431', name='square_root', id='aba0847c-ce30-4062-861a-d5692a09e7e5', tool_call_id='call_nSjfIVuvsMdRanQLvaeoRjX6'),
#  AIMessage(content='The square root of 467 is approximately 21.61018278497431 (about 21.6102 when rounded). Would you like me to also compute 467 squared?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 366, 'prompt_tokens': 193, 'total_tokens': 559, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DSCcFyA6ncKfsbibvTyIA37Esb1CP', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d6ad8-3c65-7562-b858-d6542dc3671b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 193, 'output_tokens': 366, 'total_tokens': 559, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}})]

# %%
print(response["messages"][1].tool_calls)
# Out:
# [{'name': 'square_root', 'args': {'x': 467}, 'id': 'call_nSjfIVuvsMdRanQLvaeoRjX6', 'type': 'tool_call'}]
