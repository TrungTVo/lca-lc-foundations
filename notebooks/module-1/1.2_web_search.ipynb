# %% [markdown]
# ## Without web search

# %%
from dotenv import load_dotenv
import os
from pprint import pprint
from langchain.agents import create_agent
from langchain.messages import HumanMessage

load_dotenv()
# Out:
# True

# %%
agent = create_agent(
    model="gpt-5-nano"
)

# %%
question = HumanMessage(content="How up to date is your training knowledge?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
print(response['messages'][-1].content)
# Out:
# Up to June 2024 for the core training data. I don’t have real-time web access unless a browsing tool is enabled in your session, so I can’t automatically fetch post-2024 events unless you provide them or I’m asked to browse.
#
# If you want the latest info, I can:
# - Use a browser tool (if available in this session) to look up current events or recent releases.
# - Rely on you to share recent details, and I can help analyze or summarize them.
#
# Note: For fast-changing topics (news, tech releases, laws, etc.), I’ll do best with explicit permission to browse or with user-provided sources.

# %% [markdown]
# ## Add web search tool

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient(api_key=os.getenv("TAVILY_API_KEY"))

@tool
def web_search(query: str) -> Dict[str, Any]:
    """Search the web for information"""
    return tavily_client.search(query=query, search_depth="basic", max_results=4, include_answer='basic')

web_search.invoke("Who is the current mayor of San Francisco?")
# Out:
# {'query': 'Who is the current mayor of San Francisco?',
#  'follow_up_questions': None,
#  'answer': 'Daniel Lurie is the current mayor of San Francisco, having assumed office on January 8, 2025, and his term ends on January 8, 2029.',
#  'images': [],
#  'results': [{'url': 'https://en.wikipedia.org/wiki/Mayor_of_San_Francisco',
#    'title': 'Mayor of San Francisco - Wikipedia',
#    'content': 'The current mayor is Democrat Daniel Lurie.',
#    'score': 0.9996699,
#    'raw_content': None},
#   {'url': 'https://apnews.com/article/san-francisco-new-mayor-liberal-city-81ea0a7b37af6cbb68aea7ef5cc6a4f0',
#    'title': "San Francisco's new mayor is starting to unite the fractured city",
#    'content': 'San Francisco Mayor Daniel Lurie, a political newcomer and Levi Strauss heir, has marked his first 100 days with a hands-on, business-friendly approach.',
#    'score': 0.9979966,
#    'raw_content': None},
#   {'url': 'https://www.sf.gov/departments--office-mayor',
#    'title': 'Office of the Mayor - SF.gov',
#    'content': 'Daniel Lurie is the 46th Mayor of the City and County of San Francisco.',
#    'score': 0.993255,
#    'raw_content': None},
#   {'url': 'https://ballotpedia.org/Daniel_Lurie',
#    'title': 'Daniel Lurie - Ballotpedia',
#    'content': 'Daniel Lurie is the Mayor of San Francisco in California. He assumed office on January 8, 2025. His current term ends on January 8, 2029.',
#    'score': 0.99155444,
#    'raw_content': None}],
#  'response_time': 0.93,
#  'request_id': '1e6e940c-6fba-4b8f-94ea-f4d630294810'}

# %%
agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search]
)

question = HumanMessage(content="Who is the current mayor of San Francisco?")

response = agent.invoke(
    input={"messages": [question]}
)

# %%
pprint(response['messages'])
# Out:
# [HumanMessage(content='Who is the current mayor of San Francisco?', additional_kwargs={}, response_metadata={}, id='33dac8bf-5123-4a91-926b-a75ed14f9fd1'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 542, 'prompt_tokens': 133, 'total_tokens': 675, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DSDxGt5KhlHp4PN3WTN7rm2f3ASjw', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d6b26-ca33-7993-acc3-9b8382c320b1-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'current mayor of San Francisco 2026'}, 'id': 'call_iienyJz7tbruZVRzMDZHlTQN', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 133, 'output_tokens': 542, 'total_tokens': 675, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}}),
#  ToolMessage(content='{"query": "current mayor of San Francisco 2026", "follow_up_questions": null, "answer": "Daniel Lurie is the current mayor of San Francisco, serving since 2025, and his term will end in 2029. He was elected in 2024 and assumed office on January 8, 2025.", "images": [], "results": [{"url": "https://www.sf.gov/departments--office-mayor", "title": "Office of the Mayor - SF.gov", "content": "Daniel Lurie is the 46th Mayor of the City and County of San Francisco ... April 6, 2026 · Mayor Lurie Announces Appointments to SFMTA Board, Citizens", "score": 0.8524574, "raw_content": null}, {"url": "https://ballotpedia.org/Daniel_Lurie", "title": "Daniel Lurie - Ballotpedia", "content": "Daniel Lurie is the Mayor of San Francisco in California. He assumed office on January 8, 2025. His current term ends on January 8, 2029.", "score": 0.68191797, "raw_content": null}, {"url": "https://en.wikipedia.org/wiki/Mayor_of_San_Francisco", "title": "Mayor of San Francisco - Wikipedia", "content": "Mayor of San Francisco ; Flag of San Francisco. Incumbent Daniel Lurie. since January 8, 2025. Government of San Francisco ; Flag of San Francisco. Incumbent", "score": 0.65914243, "raw_content": null}, {"url": "https://www.instagram.com/danielluriesf/", "title": "Daniel Lurie (@danielluriesf) • Instagram photos and videos", "content": "241K followers · 1 following · 1546 posts · @danielluriesf: “丹尼爾·羅偉 46th Mayor of the City and County of San Francisco.”", "score": 0.37744942, "raw_content": null}], "response_time": 1.11, "request_id": "84abb023-a0a7-42a3-8507-c6a8c637aa5a"}', name='web_search', id='dfa069f9-bd59-4ebf-924f-ed833ceff57a', tool_call_id='call_iienyJz7tbruZVRzMDZHlTQN'),
#  AIMessage(content='Daniel Lurie is the current mayor of San Francisco. He assumed office January 8, 2025, after winning the 2024 election, and his term runs through January 8, 2029. If you’d like, I can provide official sources for verification.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1089, 'prompt_tokens': 646, 'total_tokens': 1735, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1024, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DSDxN2w4rjYvvWo5Txnuloh8YFtB3', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d6b26-e673-7543-a0d9-92e9bc529f55-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 646, 'output_tokens': 1089, 'total_tokens': 1735, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1024}})]

# %% [markdown]
# trace: https://smith.langchain.com/public/59432173-0dd6-49e8-9964-b16be6048426/r
